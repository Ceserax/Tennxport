# %%
import pandas as pd 
import numpy as np

# %%
# df = pd.read_csv('/Users/keeskoot/Downloads/export-2.csv', ",")
df = pd.read_excel('/Users/keeskoot/Desktop/Epex_2021/export-2.xlsx')

# %%
df['datum'] = pd.to_datetime(df["datum"].dt.strftime('%Y-%m-%d-%H-%M'))
df['datum'] = pd.date_range(start ='1-1-2021 00:00', 
         end ='28-10-2021 00:00', freq ='min')

# %%
df.plot(x = 'datum', y = 'Mid_prijs_opregelen', figsize= (15,3),grid=True)
# Out:
# <AxesSubplot:xlabel='datum'>

# %%
df.plot(x = 'datum', y = 'Hoogste_prijs_opregelen', figsize= (15,3),color= 'gold', grid=True)
# Out:
# <AxesSubplot:xlabel='datum'>

# %%
df.plot(x = 'datum', y = 'Laagste_prijs_afregelen', figsize= (15,3),color='red', grid=True)
# Out:
# <AxesSubplot:xlabel='datum'>

# %%
df1 = pd.read_excel('/Users/keeskoot/Desktop/Epex_2021/Netmeting1_schoon1_ ABC Westland - Poeldijk.xlsx')

# %%
df1.plot(x = 'WINTERTIJD',y = 'TOTAAL',figsize= (15,3),color='green', grid=True)
# Out:
# <AxesSubplot:xlabel='WINTERTIJD'>
